# %%
import numpy as np
import pandas as pd
import os
import time
from tqdm import tqdm, trange
import sys
import matplotlib.pyplot as plt

# %%
# variaveis
L = 100 # lado do lattice
n_lagartos = L**2 # lagartos que cabem no lattice
estrategias = ['O', 'Y', 'B'] # estratégias possíveis
b = 2 # ganho em fitness ao vencer
c = 1.5 # ganho em fitness ao perder
matriz_payoff = np.array([[1, b-c, b],
                          [b, 1, b-c],
                          [b-c, b, 1]])
index_map = {'O': 0, 'Y': 1, 'B': 2}
n_geracoes = 300
n_pop = 1 # número de populações independentes
prob_mutacao = None # probabilidade de mutação a cada geração
output_dir = "C:/Unicamp/mestrado/simulacoes/RPS-python/RPS-POO/outputs/teste/vizinhanca_adaptativa/" # diretório para salvar os resultados
os.makedirs(output_dir, exist_ok=True)

# %%
class Lagarto:
  def __init__(self, i, j, estrategia, fitness, coord_vizinhos, estrategia_vizinhos, coord_vizinhanca_extendida, estrategia_vizinhanca_extendida, t, n_vizinhos, n_vizinhos_realizado):
    self.i = i # linha
    self.j = j # coluna
    self.estrategia = estrategia
    self.fitness = 0 # inicia com 0 de fitness
    self.coord_vizinhos = [] # lista vazia para adicionar as coordenadas dos vizinhos
    self.estrategia_vizinhos = [] # lista vazia para adicionar as estratégias dos vizinhos
    self.coord_vizinhanca_extendida = []
    self.estrategia_vizinhanca_extendida = []
    self.t = 0 # determina a geracao do lagarto
    self.n_vizinhos = n_vizinhos # número de vizinhos
    self.n_vizinhos_realizado = 0 # número de vizinhos

  def calcular_coord_vizinhos(self, L): # obtém as coordenadas dos vizinhos

    lista_vizinhos = []
    vizinhos_possiveis = []
    n_v = self.n_vizinhos

    for dx in range(-3, 4): 
        for dy in range(-3, 4):
            if dx == 0 and dy == 0: # ignora ele mesmo
                continue
            ni = (self.i + dx) % L # fronteiras periódicas
            nj = (self.j + dy) % L # fronteiras periódicas
            vizinhos_possiveis.append(((ni, nj), max(abs(dx), abs(dy)))) # armazena a coordenada dos vizinhos possíveis e a sua distância até o lagarto atual
        # Ordena os vizinhos por distância (mais próximos primeiro)
        vizinhos_possiveis.sort(key=lambda x: x[1])
        lista_vizinhos = [coord for coord, _ in vizinhos_possiveis[:n_v]]

    self.coord_vizinhos = lista_vizinhos # armazena as coordenadas dos vizinhos na variável do lagarto

  def obter_estrategia_vizinhos(self, matriz_posicao): # dadas as coordenadas, obtém a estratégia do lagarto que ocupa aquela posição
      self.estrategia_vizinhos = [matriz_posicao[ni, nj] for ni, nj in self.coord_vizinhos] 

  def mutacao(self, prob_mutacao): # função de mutação
    if np.random.rand() < prob_mutacao: # sorteia um valor entre 0 e 1, se for menor que a probabilidade de mutação, o lagarto muda de estratégia
        estrategias_possiveis = [e for e in estrategias if e != self.estrategia] # obtém as estratégias possíveis, exceto a atual
        self.estrategia = np.random.choice(estrategias_possiveis) # escolhe uma nova estratégia aleatoriamente para mutar

  def calcular_n_vizinhos(self): # calcula o número de vizinhos efetivo
      self.n_vizinhos_realizado = len(self.estrategia_vizinhos) + len(self.estrategia_vizinhanca_extendida) # soma os vizinhos diretos e os da vizinhança estendida

def calcular_media_vizinhos(lagartos, estrategias): # calcula a média de vizinhos para cada estratégia
    medias = []
    for e in estrategias:
        viz = [lag.n_vizinhos_realizado for lag in lagartos if lag.estrategia == e]
        medias.append(np.mean(viz) if len(viz) > 0 else 0) # se não houver lagartos com a estratégia, a média é 0
    return medias # retorna a média de vizinhos para cada estratégia

def ajustar_vizinhos_reciprocos(lagartos): # garante que, se A é vizinho de B, B também é vizinho de A, pois as interações são recíprocas
    mapa = {(l.i, l.j): l for l in lagartos} # dicionário pra acessar lagartos pela posição

    for l in lagartos:
        for (ni, nj) in l.coord_vizinhos: # vai em todos os vizinhos do lagarto atual (l)
            vizinho = mapa[(ni, nj)]
            # se o lagarto atual (l) não estiver na lista de vizinhos do vizinho, adiciona em vizinhanca_extendida
            if (l.i, l.j) not in vizinho.coord_vizinhos:
                vizinho.estrategia_vizinhanca_extendida.append(str(l.estrategia)) 
                vizinho.coord_vizinhanca_extendida.append((l.i, l.j))

# %%
def criar_lagartos(n_lagartos, L, estrategias): # define as posições e estratégias dos lagartos no t = 0
  lista_lagartos = []

  # posições iniciais aleatórias
  all_positions = [(i, j) for i in range(L) for j in range(L)] # forma todas as posições possíveis em um lattice
  unique_positions_indices = np.random.choice(len(all_positions), n_lagartos, replace=False) # determina o índice de onde vai ficar cada posição
  unique_positions = [all_positions[i] for i in unique_positions_indices] # basicamente, ele embaralhou as posições

  for g in range(n_lagartos):
    i, j = unique_positions[g] # posição na matriz
    estrategia = np.random.choice(estrategias) # sorteia a estrategia
    n_vizinho = np.random.randint(1, 25) # número de vizinhos para cada lagarto (1 a 24)
    lista_lagartos.append(Lagarto(i, j, estrategia, 0, [], [], [], [], 0, n_vizinho, 0)) # cria o lagarto com sua posição e identidade
  return lista_lagartos

def calcular_fitness(lagarto, matriz_payoff, index_map, matriz_posicao): # função para calcular o fitness do lagarto
    fitness_total = 0 # inicia no 0
    
    todos_vizinhos = set(lagarto.coord_vizinhos + lagarto.coord_vizinhanca_extendida) # junta todos os vizinhos (normais e estendidos) em um set para evitar que um vizinho seja contado duas vezes
    for ni, nj in todos_vizinhos:
        vizinho_estrat = matriz_posicao[ni, nj] # pega a estratégia do vizinho dadas as suas coordenadas
        if vizinho_estrat is not None:
            fitness_total += matriz_payoff[index_map[lagarto.estrategia], index_map[vizinho_estrat]] # calcula o payoff do lagarto contra o vizinho de acordo com a matriz de payoff e soma ao fitness total
    lagarto.fitness = fitness_total
    return fitness_total

calcular_freq = lambda mat: np.array([np.sum(mat == s) / (L ** 2) for s in ['O', 'Y', 'B']]) # calcula a frequência de cada estratégia no lattice na ordem O, Y, B

# %%
def atualizar_lagartos(lagartos): # função que atualiza as estratégias dos lagartos com base no fitness dos vizinhos
    novas_estrategias = {} # Dicionário para armazenar as novas estratégias
    novas_vizinhancas = {} # Dicionário para armazenar as novas vizinhanças

    mapa = {(l.i, l.j): l for l in lagartos} # dicionário para acessar lagartos pela posição

    for lagarto in lagartos:
        melhor_estrategia = lagarto.estrategia # inicia com a própria estratégia
        maior_fitness = lagarto.fitness # verifica o fitness do próprio lagarto
        melhor_vizinhanca = lagarto.n_vizinhos

        # verifica o fitness dos vizinhos normais
        for (ni, nj) in lagarto.coord_vizinhos:
            vizinho = mapa[(ni, nj)] # usa o dicionário para achar o vizinho
            if vizinho.fitness > maior_fitness: # se o fitness do vizinho for maior que o maior fitness atual
                maior_fitness = vizinho.fitness # atualiza o maior fitness
                melhor_estrategia = vizinho.estrategia # atualiza a melhor estratégia
                melhor_vizinhanca = vizinho.n_vizinhos
                # se houver empate de fitness ou for menor, mantém a estratégia atual (não muda)

        # verifica o fitness dos vizinhos extendidos
        for (ni, nj) in lagarto.coord_vizinhanca_extendida:
            vizinho = mapa[(ni, nj)] 
            if vizinho.fitness > maior_fitness:
                maior_fitness = vizinho.fitness
                melhor_estrategia = vizinho.estrategia
                melhor_vizinhanca = vizinho.n_vizinhos

        novas_estrategias[(lagarto.i, lagarto.j)] = melhor_estrategia # armazena a nova estratégia no dicionário
        novas_vizinhancas[(lagarto.i, lagarto.j)] = melhor_vizinhanca # armazena a nova vizinhança no dicionário

    # atualiza as estratégias de todos os lagartos simultaneamente
    for lagarto in lagartos:
        lagarto.estrategia = novas_estrategias[(lagarto.i, lagarto.j)] # evita que a atualização de um lagarto influencie outro na mesma geração (sem sobreposição de geração)
        lagarto.n_vizinhos = novas_vizinhancas[(lagarto.i, lagarto.j)]
    
    return lagartos

# %%
# iniciando a simulação
def simulacao(n_geracoes, L, n_lagartos, estrategias, matriz_payoff, index_map, n_pop, prob_mutacao = None, seed = None):
    matriz_frequencias = np.full((n_geracoes + 1, n_pop, len(estrategias)), np.nan, dtype=float) # cria uma matriz para armazenar as frequências em cada instante dos loops
    matriz_n_vizinhos_media = np.full((n_geracoes + 1, n_pop, len(estrategias)), np.nan, dtype=float) # cria uma matriz para armazenar vizinhos
    n_vizinhos_individual = []  # lista para armazenar todos os números de vizinhos
    historico_estrategias = [] # lista para armazenar o histórico de estratégias de cada população

    for pop in range(n_pop): # loop para cada população independente
      if seed is not None:
        np.random.seed(seed + pop) # coloca uma semente diferente pra cada pop, garantindo independência e reproducibilidade

      frequencias = [] # vai armazenar as frequências ao longo das gerações para essa população
      lista_lagartos = criar_lagartos(n_lagartos, L, estrategias) # cria os lagartos
      matriz_posicao = np.full((L, L), None) # cria uma matriz vazia com None
      n_vizinhos_pop = []  # [pop][t][i]
      historico_estrategias_pop = []

      for lagarto in lista_lagartos:
        matriz_posicao[lagarto.i, lagarto.j] = str(lagarto.estrategia) # cria a matriz de posições de acordo com os lagartos

      frequencias.append(calcular_freq(matriz_posicao)) # calcula a frequência inicial
      n_vizinhos_pop.append([lagarto.n_vizinhos for lagarto in lista_lagartos])  # geração inicial
      historico_estrategias_pop.append([lagarto.estrategia for lagarto in lista_lagartos])  # histórico de estratégias

      for t in range(1, n_geracoes + 1): # loop para cada geração dentro da população
        # determinando os vizinhos
        for lagarto in lista_lagartos:
          lagarto.calcular_coord_vizinhos(L) # calcula as coordenadas dos vizinhos
          lagarto.obter_estrategia_vizinhos(matriz_posicao) # obtém as estratégias dos vizinhos
          # zera a vizinhança estendida para recalcular a cada lagarto
          lagarto.coord_vizinhanca_extendida = [] 
          lagarto.estrategia_vizinhanca_extendida = [] 

        ajustar_vizinhos_reciprocos(lista_lagartos) # ajusta as vizinhanças recíprocas

        for lagarto in lista_lagartos:
          lagarto.calcular_n_vizinhos() # calcula o número de vizinhos efetivo
        
        n_vizinhos_geracao = [lagarto.n_vizinhos_realizado for lagarto in lista_lagartos]
        n_vizinhos_pop.append(n_vizinhos_geracao)
      
        matriz_n_vizinhos_media[t, pop, :] = calcular_media_vizinhos(lista_lagartos, estrategias) # calcula a média de vizinhos para cada estratégia e armazena na matriz n_vizinhos
        #print(matriz_n_vizinhos[t, pop, :]) # debug

        # calculando o fitness
        for lagarto in lista_lagartos:
          calcular_fitness(lagarto, matriz_payoff, index_map, matriz_posicao) # calcula o fitness do lagarto de acordo com seus vizinhos e a matriz de fitness

        lista_lagartos = atualizar_lagartos(lista_lagartos) # atualiza as estratégias dos lagartos de acordo com o maior fitness dos vizinhos

        if prob_mutacao is not None:
          for lagarto in lista_lagartos:
            lagarto.mutacao(prob_mutacao) # aplica a mutação

        # atualiza a matriz de posição com as novas estratégias e com as mutações
        matriz_posicao = np.full((L, L), None)
        for lagarto in lista_lagartos:
          matriz_posicao[lagarto.i, lagarto.j] = str(lagarto.estrategia)
        #print(matriz_posicao)

        historico_estrategias_pop.append([lagarto.estrategia for lagarto in lista_lagartos])  # histórico de estratégias
        frequencias.append(calcular_freq(matriz_posicao)) # calcula a frequência dessa geração e armazena em frequencias

        for lagarto in lista_lagartos:
            lagarto.t += 1 # incrementa a geração do lagarto
        
      frequencias = np.array(frequencias)
      n_vizinhos_individual.append(n_vizinhos_pop)
      historico_estrategias.append(historico_estrategias_pop)
      for t in range(n_geracoes + 1):
        matriz_frequencias[t, pop, :] = frequencias[t]


    return matriz_frequencias, matriz_n_vizinhos_media, n_vizinhos_individual, historico_estrategias

freq, n_vizinhos, n_vizinhos_individual, historico_estrategias = simulacao(n_geracoes, L, n_lagartos, estrategias, matriz_payoff, index_map, n_pop, prob_mutacao, seed = 2)

# %%
# salva a matriz de vizinhos como DataFrame formato tidy
linhas = []
n_vizinhos = np.array(n_vizinhos, dtype=float)  # converte para float para evitar problemas com None

for t in range(n_vizinhos.shape[0]):          # gerações
    for pop in range(n_vizinhos.shape[1]):    # populações
        for idx, strategy in enumerate(estrategias):  # estratégias
            linhas.append({
                "t": t,                        # geração
                "pop": pop,                    # população
                "estrategia": strategy,        # estratégia
                "n_vizinhos": n_vizinhos[t, pop, idx]  # média de vizinhos
            })

df_n_vizinhos = pd.DataFrame(linhas)

cores = {"O": "#FD9800", "B": "#0047B3", "Y": "#FFF237"}

plt.figure(figsize=(12, 6))

# loop por população e estratégia
for pop in df_n_vizinhos["pop"].unique():
    for strategy in estrategias:
        dados = df_n_vizinhos[(df_n_vizinhos["pop"] == pop) & (df_n_vizinhos["estrategia"] == strategy)]
        plt.plot(
            dados["t"],                # eixo x: gerações
            dados["n_vizinhos"],       # eixo y: vizinhos
            label=f"{strategy} (sim {pop+1})" if pop == 0 else None,
            color=cores[strategy],
            alpha=1
        )
plt.title("Vizinhos ao longo do tempo")
plt.xlabel("Gerações")
plt.ylabel("Número de vizinhos médio dos lagartos")
plt.grid(True)
plt.show()

# %%
def funcao_investimento(I, k, c1):
    b = 1 - np.e**(-k * I)
    c = c1*I
    return b, c

plt.figure(figsize=(10, 6))
I_values = np.linspace(0, 5, 100)

b_values, c_values = funcao_investimento(I_values, 1.5, 0.2)
plt.plot(I_values, b_values, label='Benefício (b)', color='blue')
plt.plot(I_values, c_values, label='Custo (c)', color='red')

plt.title('Função de Investimento')
plt.xlabel('Investimento (I)')
plt.ylabel('Retorno')
plt.legend()
plt.grid()
plt.show()

# %%
# Exemplo: mostrar a média e o desvio padrão do número de vizinhos em cada geração para a primeira população
for t, n_vizinhos_geracao in enumerate(n_vizinhos_individual[0]):
    media = np.mean(n_vizinhos_geracao)
    desvio = np.std(n_vizinhos_geracao)
    print(f"Geração {t}: média={media:.2f}, desvio={desvio:.2f}")
# Out:
# Geração 0: média=12.47, desvio=6.92
# Geração 1: média=17.78, desvio=4.23
# Geração 2: média=21.05, desvio=3.80
# Geração 3: média=21.94, desvio=3.48
# Geração 4: média=21.59, desvio=4.12
# Geração 5: média=21.28, desvio=4.54
# Geração 6: média=21.04, desvio=4.74
# Geração 7: média=20.70, desvio=5.04
# Geração 8: média=20.35, desvio=5.33
# Geração 9: média=20.22, desvio=5.32
# Geração 10: média=20.40, desvio=5.05
# Geração 11: média=20.66, desvio=4.81
# Geração 12: média=20.89, desvio=4.63
# Geração 13: média=21.02, desvio=4.59
# Geração 14: média=21.20, desvio=4.35
# Geração 15: média=21.28, desvio=4.26
# Geração 16: média=21.22, desvio=4.45
# Geração 17: média=21.02, desvio=4.58
# Geração 18: média=20.91, desvio=4.76
# Geração 19: média=21.09, desvio=4.66
# Geração 20: média=21.40, desvio=4.34
# Geração 21: média=21.56, desvio=4.05
# Geração 22: média=21.63, desvio=3.99
# Geração 23: média=21.59, desvio=4.08
# Geração 24: média=21.35, desvio=4.32
# Geração 25: média=21.37, desvio=4.32
# Geração 26: média=21.38, desvio=4.49
# Geração 27: média=21.49, desvio=4.44
# Geração 28: média=21.58, desvio=4.29
# Geração 29: média=21.73, desvio=4.13
# Geração 30: média=21.76, desvio=4.06
# Geração 31: média=21.67, desvio=4.12
# Geração 32: média=21.57, desvio=4.11
# Geração 33: média=21.57, desvio=4.11
# Geração 34: média=21.60, desvio=4.09
# Geração 35: média=21.69, desvio=4.05
# Geração 36: média=21.78, desvio=4.00
# Geração 37: média=21.78, desvio=4.02
# Geração 38: média=21.73, desvio=4.03
# Geração 39: média=21.65, desvio=4.08
# Geração 40: média=21.73, desvio=3.95
# Geração 41: média=21.87, desvio=3.79
# Geração 42: média=21.85, desvio=3.79
# Geração 43: média=21.80, desvio=3.80
# Geração 44: média=21.75, desvio=3.86
# Geração 45: média=21.66, desvio=3.96
# Geração 46: média=21.52, desvio=4.21
# Geração 47: média=21.53, desvio=4.11
# Geração 48: média=21.51, desvio=4.08
# Geração 49: média=21.51, desvio=4.05
# Geração 50: média=21.50, desvio=4.08
# Geração 51: média=21.51, desvio=4.10
# Geração 52: média=21.39, desvio=4.32
# Geração 53: média=21.22, desvio=4.35
# Geração 54: média=21.15, desvio=4.41
# Geração 55: média=21.37, desvio=4.09
# Geração 56: média=21.49, desvio=3.94
# Geração 57: média=21.43, desvio=4.00
# Geração 58: média=21.37, desvio=4.07
# Geração 59: média=21.33, desvio=4.15
# Geração 60: média=21.14, desvio=4.38
# Geração 61: média=21.14, desvio=4.43
# Geração 62: média=21.31, desvio=4.22
# Geração 63: média=21.38, desvio=4.09
# Geração 64: média=21.25, desvio=4.14
# Geração 65: média=21.10, desvio=4.26
# Geração 66: média=21.19, desvio=4.28
# Geração 67: média=21.21, desvio=4.39
# Geração 68: média=21.06, desvio=4.54
# Geração 69: média=21.09, desvio=4.44
# Geração 70: média=21.15, desvio=4.37
# Geração 71: média=21.15, desvio=4.41
# Geração 72: média=21.13, desvio=4.37
# Geração 73: média=21.21, desvio=4.37
# Geração 74: média=21.24, desvio=4.38
# Geração 75: média=21.09, desvio=4.57
# Geração 76: média=21.20, desvio=4.46
# Geração 77: média=21.31, desvio=4.25
# Geração 78: média=21.37, desvio=4.23
# Geração 79: média=21.31, desvio=4.23
# Geração 80: média=21.19, desvio=4.40
# Geração 81: média=21.03, desvio=4.69
# Geração 82: média=20.81, desvio=5.00
# Geração 83: média=20.47, desvio=5.33
# Geração 84: média=20.62, desvio=5.16
# Geração 85: média=20.88, desvio=4.93
# Geração 86: média=21.02, desvio=4.74
# Geração 87: média=21.22, desvio=4.53
# Geração 88: média=21.27, desvio=4.43
# Geração 89: média=21.32, desvio=4.32
# Geração 90: média=21.36, desvio=4.23
# Geração 91: média=21.42, desvio=4.19
# Geração 92: média=21.54, desvio=4.08
# Geração 93: média=21.58, desvio=4.12
# Geração 94: média=21.51, desvio=4.29
# Geração 95: média=21.20, desvio=4.71
# Geração 96: média=20.85, desvio=5.01
# Geração 97: média=20.76, desvio=5.14
# Geração 98: média=20.47, desvio=5.52
# Geração 99: média=20.39, desvio=5.66
# Geração 100: média=20.28, desvio=5.83
# Geração 101: média=19.99, desvio=6.05
# Geração 102: média=19.74, desvio=6.19
# Geração 103: média=19.70, desvio=6.15
# Geração 104: média=19.86, desvio=5.94
# Geração 105: média=20.27, desvio=5.56
# Geração 106: média=20.79, desvio=5.08
# Geração 107: média=21.19, desvio=4.69
# Geração 108: média=21.31, desvio=4.51
# Geração 109: média=21.29, desvio=4.46
# Geração 110: média=21.33, desvio=4.33
# Geração 111: média=21.45, desvio=4.22
# Geração 112: média=21.64, desvio=4.01
# Geração 113: média=21.86, desvio=3.78
# Geração 114: média=21.93, desvio=3.59
# Geração 115: média=21.94, desvio=3.64
# Geração 116: média=21.82, desvio=3.78
# Geração 117: média=21.60, desvio=4.02
# Geração 118: média=21.46, desvio=4.14
# Geração 119: média=21.71, desvio=3.95
# Geração 120: média=21.88, desvio=3.80
# Geração 121: média=21.92, desvio=3.71
# Geração 122: média=21.81, desvio=3.90
# Geração 123: média=21.67, desvio=4.01
# Geração 124: média=21.43, desvio=4.31
# Geração 125: média=21.42, desvio=4.32
# Geração 126: média=21.75, desvio=3.87
# Geração 127: média=22.02, desvio=3.64
# Geração 128: média=22.16, desvio=3.46
# Geração 129: média=21.90, desvio=3.82
# Geração 130: média=21.91, desvio=3.85
# Geração 131: média=21.82, desvio=4.08
# Geração 132: média=21.92, desvio=3.92
# Geração 133: média=22.06, desvio=3.67
# Geração 134: média=22.02, desvio=3.70
# Geração 135: média=21.93, desvio=3.78
# Geração 136: média=21.65, desvio=4.08
# Geração 137: média=21.65, desvio=4.20
# Geração 138: média=21.67, desvio=4.25
# Geração 139: média=21.88, desvio=4.04
# Geração 140: média=21.96, desvio=3.92
# Geração 141: média=21.93, desvio=3.82
# Geração 142: média=21.73, desvio=4.07
# Geração 143: média=21.60, desvio=4.20
# Geração 144: média=21.71, desvio=4.22
# Geração 145: média=21.85, desvio=4.11
# Geração 146: média=21.88, desvio=4.07
# Geração 147: média=21.93, desvio=3.92
# Geração 148: média=21.88, desvio=3.92
# Geração 149: média=21.82, desvio=3.98
# Geração 150: média=21.75, desvio=4.11
# Geração 151: média=21.88, desvio=4.00
# Geração 152: média=21.96, desvio=3.99
# Geração 153: média=22.00, desvio=3.99
# Geração 154: média=21.81, desvio=4.19
# Geração 155: média=21.67, desvio=4.35
# Geração 156: média=21.41, desvio=4.67
# Geração 157: média=21.11, desvio=5.01
# Geração 158: média=20.93, desvio=5.17
# Geração 159: média=20.85, desvio=5.33
# Geração 160: média=20.93, desvio=5.26
# Geração 161: média=20.97, desvio=5.15
# Geração 162: média=21.18, desvio=4.88
# Geração 163: média=21.32, desvio=4.70
# Geração 164: média=21.36, desvio=4.62
# Geração 165: média=21.63, desvio=4.32
# Geração 166: média=21.80, desvio=4.17
# Geração 167: média=21.96, desvio=3.98
# Geração 168: média=21.99, desvio=3.97
# Geração 169: média=21.95, desvio=3.98
# Geração 170: média=21.81, desvio=4.16
# Geração 171: média=21.78, desvio=4.21
# Geração 172: média=21.82, desvio=4.12
# Geração 173: média=21.67, desvio=4.35
# Geração 174: média=21.72, desvio=4.33
# Geração 175: média=21.79, desvio=4.22
# Geração 176: média=21.85, desvio=4.10
# Geração 177: média=21.89, desvio=4.10
# Geração 178: média=21.74, desvio=4.32
# Geração 179: média=21.53, desvio=4.50
# Geração 180: média=21.59, desvio=4.44
# Geração 181: média=21.57, desvio=4.52
# Geração 182: média=21.56, desvio=4.42
# Geração 183: média=21.66, desvio=4.32
# Geração 184: média=21.59, desvio=4.44
# Geração 185: média=21.30, desvio=4.75
# Geração 186: média=20.99, desvio=5.05
# Geração 187: média=20.99, desvio=5.05
# Geração 188: média=21.01, desvio=5.04
# Geração 189: média=21.15, desvio=4.84
# Geração 190: média=21.48, desvio=4.49
# Geração 191: média=21.73, desvio=4.25
# Geração 192: média=21.59, desvio=4.43
# Geração 193: média=21.47, desvio=4.60
# Geração 194: média=21.64, desvio=4.38
# Geração 195: média=21.75, desvio=4.20
# Geração 196: média=21.68, desvio=4.21
# Geração 197: média=21.74, desvio=4.12
# Geração 198: média=21.80, desvio=4.11
# Geração 199: média=21.60, desvio=4.36
# Geração 200: média=21.39, desvio=4.61
# Geração 201: média=21.45, desvio=4.50
# Geração 202: média=21.58, desvio=4.36
# Geração 203: média=21.59, desvio=4.30
# Geração 204: média=21.58, desvio=4.23
# Geração 205: média=21.65, desvio=4.13
# Geração 206: média=21.54, desvio=4.33
# Geração 207: média=21.36, desvio=4.53
# Geração 208: média=21.49, desvio=4.38
# Geração 209: média=21.66, desvio=4.21
# Geração 210: média=21.66, desvio=4.28
# Geração 211: média=21.58, desvio=4.31
# Geração 212: média=21.53, desvio=4.31
# Geração 213: média=21.33, desvio=4.60
# Geração 214: média=21.30, desvio=4.63
# Geração 215: média=21.42, desvio=4.54
# Geração 216: média=21.55, desvio=4.42
# Geração 217: média=21.51, desvio=4.51
# Geração 218: média=21.46, desvio=4.46
# Geração 219: média=21.44, desvio=4.45
# Geração 220: média=21.35, desvio=4.54
# Geração 221: média=21.15, desvio=4.74
# Geração 222: média=21.19, desvio=4.78
# Geração 223: média=21.26, desvio=4.69
# Geração 224: média=21.24, desvio=4.79
# Geração 225: média=21.22, desvio=4.72
# Geração 226: média=21.21, desvio=4.74
# Geração 227: média=21.25, desvio=4.68
# Geração 228: média=21.22, desvio=4.77
# Geração 229: média=21.36, desvio=4.67
# Geração 230: média=21.36, desvio=4.64
# Geração 231: média=21.26, desvio=4.73
# Geração 232: média=21.19, desvio=4.73
# Geração 233: média=21.20, desvio=4.64
# Geração 234: média=21.08, desvio=4.83
# Geração 235: média=21.16, desvio=4.77
# Geração 236: média=21.18, desvio=4.78
# Geração 237: média=21.15, desvio=4.81
# Geração 238: média=21.04, desvio=4.87
# Geração 239: média=20.92, desvio=4.95
# Geração 240: média=20.92, desvio=4.96
# Geração 241: média=21.07, desvio=4.87
# Geração 242: média=21.25, desvio=4.76
# Geração 243: média=21.33, desvio=4.70
# Geração 244: média=21.33, desvio=4.69
# Geração 245: média=21.16, desvio=4.76
# Geração 246: média=21.10, desvio=4.82
# Geração 247: média=21.14, desvio=4.81
# Geração 248: média=21.24, desvio=4.73
# Geração 249: média=21.23, desvio=4.83
# Geração 250: média=21.15, desvio=4.92
# Geração 251: média=21.00, desvio=5.04
# Geração 252: média=20.85, desvio=5.23
# Geração 253: média=20.68, desvio=5.32
# Geração 254: média=20.68, desvio=5.33
# Geração 255: média=20.85, desvio=5.12
# Geração 256: média=21.00, desvio=5.10
# Geração 257: média=20.93, desvio=5.18
# Geração 258: média=20.84, desvio=5.27
# Geração 259: média=20.79, desvio=5.25
# Geração 260: média=20.69, desvio=5.31
# Geração 261: média=20.51, desvio=5.44
# Geração 262: média=20.61, desvio=5.26
# Geração 263: média=20.89, desvio=5.12
# Geração 264: média=21.10, desvio=4.91
# Geração 265: média=21.07, desvio=5.00
# Geração 266: média=21.16, desvio=4.87
# Geração 267: média=20.99, desvio=5.02
# Geração 268: média=20.80, desvio=5.16
# Geração 269: média=20.88, desvio=5.03
# Geração 270: média=21.22, desvio=4.89
# Geração 271: média=21.16, desvio=4.93
# Geração 272: média=20.95, desvio=5.16
# Geração 273: média=20.94, desvio=5.13
# Geração 274: média=20.82, desvio=5.25
# Geração 275: média=20.64, desvio=5.32
# Geração 276: média=20.64, desvio=5.31
# Geração 277: média=20.73, desvio=5.28
# Geração 278: média=20.91, desvio=5.11
# Geração 279: média=20.93, desvio=5.04
# Geração 280: média=20.81, desvio=5.14
# Geração 281: média=20.96, desvio=5.05
# Geração 282: média=20.89, desvio=5.08
# Geração 283: média=20.71, desvio=5.30
# Geração 284: média=20.93, desvio=5.13
# Geração 285: média=21.04, desvio=5.05
# Geração 286: média=20.79, desvio=5.34
# Geração 287: média=20.64, desvio=5.47
# Geração 288: média=20.54, desvio=5.47
# Geração 289: média=20.33, desvio=5.63
# Geração 290: média=20.31, desvio=5.67
# Geração 291: média=20.90, desvio=5.19
# Geração 292: média=21.07, desvio=5.07
# Geração 293: média=20.79, desvio=5.26
# Geração 294: média=20.66, desvio=5.37
# Geração 295: média=20.74, desvio=5.23
# Geração 296: média=20.71, desvio=5.29
# Geração 297: média=20.92, desvio=5.20
# Geração 298: média=21.41, desvio=4.70
# Geração 299: média=21.44, desvio=4.65
# Geração 300: média=21.15, desvio=4.87

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

estrategia_cor = {'O': 'orange', 'Y': 'yellowgreen', 'B': 'blue'}

n_geracoes = len(n_vizinhos_individual[0])
n_lagartos = len(n_vizinhos_individual[0][0])

# Converta para numpy arrays para facilitar o filtro
n_vizinhos_arr = np.array(n_vizinhos_individual[0])  # shape: (n_geracoes, n_lagartos)
estrategias_arr = np.array(historico_estrategias[0])  # shape: (n_geracoes, n_lagartos)

plt.figure(figsize=(12, 6))

for estrat, cor in estrategia_cor.items():
    # Máscara booleana para cada estratégia
    mask = (estrategias_arr == estrat)
    # Pegue os índices das gerações e dos lagartos onde a estratégia ocorre
    t_idx, i_idx = np.where(mask)
    # Pegue os valores de n_vizinhos correspondentes
    n_viz_vals = n_vizinhos_arr[t_idx, i_idx]
    plt.scatter(t_idx, n_viz_vals, color=cor, s=2, alpha=0.1, label=estrat)

plt.xlabel('Geração')
plt.ylabel('Número de vizinhos realizado')
plt.title('Distribuição do número de vizinhos por estratégia em cada geração')
plt.grid(True)
handles = [mpatches.Patch(color=c, label=e) for e, c in estrategia_cor.items()]
plt.legend(handles=handles)
plt.show()
# Out:
# c:\Users\nicko\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
